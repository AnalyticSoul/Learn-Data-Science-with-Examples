# %%
# import important libraries
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the transaction dataset
df_retail = pd.read_csv('wrangled_transactions.csv')
df_retail.head()
# Out:
#    customer_id  revenue_2019  customer_relation_days  last_purchase_days  \
# 0      12747.0        706.27                      26                  18
# 1      12748.0       4228.13                      30                   8
# 2      12826.0        155.00                      22                  22
# 3      12829.0         85.75                      17                  17
# 4      12838.0        390.79                      30                  30
#
#    number_of_purchases  avg_order_cost  revenue_2020
# 0                    2      353.135000       3489.74
# 1                   14      302.009286      29491.60
# 2                    1      155.000000       1319.72
# 3                    1       85.750000        207.25
# 4                    1      390.790000        292.34

# %%
# understand the numeric columns
print(df_retail.shape)
df_retail.describe()
# Out:
# (708, 7)
#         customer_id  revenue_2019  customer_relation_days  last_purchase_days  \
# count    708.000000    708.000000              708.000000          708.000000
# mean   15653.316384    654.627811               22.655367           19.980226
# std     1593.880573   1548.219356                5.453664            5.812940
# min    12747.000000     16.210000                8.000000            8.000000
# 25%    14341.500000    212.400000               18.000000           15.000000
# 50%    15701.000000    342.580000               23.000000           19.000000
# 75%    17078.250000    606.837500               26.500000           24.000000
# max    18260.000000  27834.610000               30.000000           30.000000
#
#        number_of_purchases  avg_order_cost   revenue_2020
# count           708.000000      708.000000     708.000000
# mean              1.405367      420.118001    4407.683206
# std               0.938460      657.895532   13824.121791
# min               1.000000       16.210000      10.000000
# 25%               1.000000      185.912500     570.637500
# 50%               1.000000      302.440000    1583.085000
# 75%               2.000000      421.255000    3573.257500
# max              14.000000    13917.305000  231822.690000

# %%
# correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
s = sns.heatmap(df_retail.corr().round(2),
                annot=True,
                cmap='RdBu',
                vmin=-1,
                vmax=1)
s.set_xticklabels(s.get_xticklabels(), rotation=90)
plt.title('Correlation Matrix')
plt.show()

# %%
# understand the relation between revenue_2019 and other columns
fig, ax = plt.subplots(1, 5, figsize=(20, 5))
for i, col in enumerate(['customer_relation_days', 'last_purchase_days', 'number_of_purchases', 'avg_order_cost', 'revenue_2020']):
    ax[i].tick_params(axis='y', rotation=60)
    sns.scatterplot(data=df_retail, x=col, y='revenue_2019', ax=ax[i])
plt.show()
